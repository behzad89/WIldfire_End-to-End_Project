# %%
import numpy as np
import pandas as pd

from sklearn.pipeline import Pipeline
from feature_engine.datetime import DatetimeFeatures
from feature_engine.timeseries.forecasting import LagFeatures

import os,glob

# %%
df = pd.read_csv('../Data/results/Train[updated].csv',parse_dates=['date'])
df.head(3)
# Out:
#          lat        lon  burn_area  climate_aet  climate_def  climate_pdsi  \
# 0 -15.858835  29.237029        0.0         1195            0           263
# 1 -15.858835  29.487029        0.0         1196            0           232
# 2 -15.858835  29.737029        0.0         1190            0           314
#
#    climate_pet  climate_pr  climate_ro  climate_soil  ...  landcover_1  \
# 0         1195         206          10          1692  ...          0.0
# 1         1196         201          10          1859  ...          0.0
# 2         1190         192          10          1677  ...          0.0
#
#    landcover_2  landcover_3  landcover_4  landcover_5  landcover_6  \
# 0     0.018654          0.0     0.714446     0.012174     0.244890
# 1     0.000000          0.0     0.654783     0.000095     0.345121
# 2     0.000000          0.0     0.516421     0.000000     0.483579
#
#    landcover_7  landcover_8  precipitation       date
# 0     0.009836          0.0       0.256932 2001-01-01
# 1     0.000000          0.0       0.273093 2001-01-01
# 2     0.000000          0.0       0.285109 2001-01-01
#
# [3 rows x 29 columns]

# %% [markdown]
# # Drop the columns

# %% [markdown]
# EDA showed that we should drop to columns as they do not have any correlation with outcome

# %%
df.drop(['climate_swe', 'landcover_3'], axis=1, inplace=True)

# %% [markdown]
# # Temporal Features

# %% [markdown]
# There are monthly, yearly, and seasonal trends in burnt areas; therefore, the Month of Year (MOY), and seasonal indicators can be generated.

# %%
FTs_To_Extract = ["month", "quarter"]

pipe = Pipeline([
    
    # create datetime features.
    ('date', DatetimeFeatures(
        variables="date",
        features_to_extract=FTs_To_Extract,
        drop_original=False
    )),
])

# Extract features.
dtfs = pipe.fit_transform(df)

dtfs.iloc[:,-2:].describe().loc[['min','max'],:]
# Out:
#      date_month  date_quarter
# min         1.0           1.0
# max        12.0           4.0

# %% [markdown]
# # Lag Features

# %%
# dtfs.index.name = 'index'
climate_columns = dtfs[[col for col in dtfs.columns if col.startswith(("climate_", "lat","lo", "p", "date_m"))]]

# %%
month_avg = climate_columns.groupby(['lat', 'lon','date_month']).mean().reset_index()
month_avg.index.name = 'index'
month_avg.head(14)
# Out:
#              lat        lon  date_month  climate_aet  climate_def  \
# index
# 0     -22.358835  31.237029           1   662.307692  1042.923077
# 1     -22.358835  31.237029           2   669.538462   846.615385
# 2     -22.358835  31.237029           3   328.461538  1114.692308
# 3     -22.358835  31.237029           4   204.000000   902.923077
# 4     -22.358835  31.237029           5    66.538462   834.000000
# 5     -22.358835  31.237029           6    55.923077   690.000000
# 6     -22.358835  31.237029           7    17.923077   835.307692
# 7     -22.358835  31.237029           8    15.923077  1147.153846
# 8     -22.358835  31.237029           9    96.461538  1346.230769
# 9     -22.358835  31.237029          10   192.615385  1498.000000
# 10    -22.358835  31.237029          11   538.692308  1092.461538
# 11    -22.358835  31.237029          12   882.923077   777.923077
# 12    -22.108835  29.487029           1   501.923077  1280.384615
# 13    -22.108835  29.487029           2   481.615385  1120.384615
#
#        climate_pdsi  climate_pet  climate_pr  climate_ro  climate_soil  \
# index
# 0        -56.076923  1705.076923   69.615385    3.307692     19.923077
# 1       -123.769231  1516.076923   71.538462    3.538462     30.769231
# 2       -128.461538  1443.153846   34.230769    1.692308     26.692308
# 3       -142.923077  1106.692308   21.230769    1.000000     24.230769
# 4       -127.923077   900.538462    6.846154    0.230769     22.384615
# 5       -115.076923   746.076923    5.769231    0.230769     20.846154
# 6       -104.307692   853.384615    1.769231    0.000000     19.846154
# 7       -112.692308  1163.153846    1.461538    0.076923     18.769231
# 8       -130.923077  1442.692308   10.076923    0.384615     18.076923
# 9       -137.307692  1690.615385   20.384615    0.923077     17.153846
# 10      -100.615385  1631.153846   56.615385    2.923077     16.461538
# 11       -53.461538  1661.000000   92.923077    4.615385     16.384615
# 12       -36.461538  1782.307692   52.769231    2.846154      2.230769
# 13      -104.307692  1602.153846   50.692308    2.384615      2.230769
#
#        climate_srad  climate_tmmn  climate_tmmx  climate_vap  climate_vpd  \
# index
# 0       2515.461538    221.384615    359.000000  2453.769231   186.307692
# 1       2642.846154    224.230769    352.846154  2540.923077   169.769231
# 2       2230.000000    205.384615    343.384615  2337.923077   160.692308
# 3       1895.076923    182.923077    330.769231  2093.769231   150.615385
# 4       1803.538462    141.307692    305.923077  1629.307692   138.923077
# 5       1584.153846    114.307692    287.307692  1407.230769   125.846154
# 6       1652.307692    105.461538    288.769231  1334.692308   130.769231
# 7       1977.000000    127.846154    313.230769  1447.615385   159.846154
# 8       2371.923077    157.769231    329.384615  1632.076923   179.384615
# 9       2450.230769    193.615385    355.384615  1978.538462   207.076923
# 10      2438.615385    210.307692    351.000000  2144.923077   195.384615
# 11      2412.307692    220.461538    356.384615  2348.153846   191.846154
# 12      2616.307692    221.692308    352.076923  2213.000000   199.692308
# 13      2748.692308    216.461538    345.461538  2233.153846   183.000000
#
#        climate_vs  precipitation
# index
# 0      178.769231       0.161206
# 1      158.076923       0.072256
# 2      174.076923       0.060118
# 3      138.846154       0.030479
# 4      104.615385       0.010238
# 5      116.153846       0.006218
# 6      137.615385       0.005040
# 7      174.230769       0.003255
# 8      198.846154       0.013364
# 9      201.692308       0.028644
# 10     192.076923       0.094109
# 11     173.923077       0.138914
# 12     190.692308       0.089938
# 13     189.076923       0.040884

# %%
lags = [1,2]
lag_cols = month_avg.drop('date_month',axis=1).columns
for l in lags:
    # Shift the timeseries index to get the lagged versions
    df_shift = month_avg[lag_cols].shift(periods=l)
    # Join back to the original dataframe
    month_avg = month_avg.merge(df_shift, on=['lat','lon','index'], how="left", suffixes=("", f"_lag_{l}"))

# %%
month_avg[['lat','lon','date_month','climate_aet','climate_aet_lag_1','climate_aet_lag_2']].head(14)
# Out:
#              lat        lon  date_month  climate_aet  climate_aet_lag_1  \
# index
# 0     -22.358835  31.237029           1   662.307692                NaN
# 1     -22.358835  31.237029           2   669.538462         662.307692
# 2     -22.358835  31.237029           3   328.461538         669.538462
# 3     -22.358835  31.237029           4   204.000000         328.461538
# 4     -22.358835  31.237029           5    66.538462         204.000000
# 5     -22.358835  31.237029           6    55.923077          66.538462
# 6     -22.358835  31.237029           7    17.923077          55.923077
# 7     -22.358835  31.237029           8    15.923077          17.923077
# 8     -22.358835  31.237029           9    96.461538          15.923077
# 9     -22.358835  31.237029          10   192.615385          96.461538
# 10    -22.358835  31.237029          11   538.692308         192.615385
# 11    -22.358835  31.237029          12   882.923077         538.692308
# 12    -22.108835  29.487029           1   501.923077                NaN
# 13    -22.108835  29.487029           2   481.615385         501.923077
#
#        climate_aet_lag_2
# index
# 0                    NaN
# 1                    NaN
# 2             662.307692
# 3             669.538462
# 4             328.461538
# 5             204.000000
# 6              66.538462
# 7              55.923077
# 8              17.923077
# 9              15.923077
# 10             96.461538
# 11            192.615385
# 12                   NaN
# 13                   NaN

# %%
landcover_df = dtfs.drop(climate_columns.columns[2:-1],axis=1)

# %%
data = month_avg.merge(landcover_df, on=['lat','lon','date_month'], how="left")

# %%
data.head()
# Out:
#          lat        lon  date_month  climate_aet  climate_def  climate_pdsi  \
# 0 -22.358835  31.237029           1   662.307692  1042.923077    -56.076923
# 1 -22.358835  31.237029           1   662.307692  1042.923077    -56.076923
# 2 -22.358835  31.237029           1   662.307692  1042.923077    -56.076923
# 3 -22.358835  31.237029           1   662.307692  1042.923077    -56.076923
# 4 -22.358835  31.237029           1   662.307692  1042.923077    -56.076923
#
#    climate_pet  climate_pr  climate_ro  climate_soil  ...  landcover_0  \
# 0  1705.076923   69.615385    3.307692     19.923077  ...          0.0
# 1  1705.076923   69.615385    3.307692     19.923077  ...          0.0
# 2  1705.076923   69.615385    3.307692     19.923077  ...          0.0
# 3  1705.076923   69.615385    3.307692     19.923077  ...          0.0
# 4  1705.076923   69.615385    3.307692     19.923077  ...          0.0
#
#    landcover_1  landcover_2  landcover_4  landcover_5  landcover_6  \
# 0          0.0     0.003074     0.184807     0.004725     0.807394
# 1          0.0     0.003381     0.157698     0.004725     0.834195
# 2          0.0     0.003996     0.158682     0.004110     0.833212
# 3          0.0     0.003381     0.162053     0.004215     0.830350
# 4          0.0     0.003381     0.137911     0.004215     0.854493
#
#    landcover_7  landcover_8       date  date_quarter
# 0          0.0          0.0 2001-01-01             1
# 1          0.0          0.0 2002-01-01             1
# 2          0.0          0.0 2003-01-01             1
# 3          0.0          0.0 2004-01-01             1
# 4          0.0          0.0 2005-01-01             1
#
# [5 rows x 57 columns]

# %%
data.isna().sum().sum()
# Out:
# 291018

# %%
data.dropna(inplace=True)

# %%
data.isna().sum().sum()
# Out:
# 0

# %%
data.to_csv('../Data/results/Train[FeatEng].csv',index=False)
